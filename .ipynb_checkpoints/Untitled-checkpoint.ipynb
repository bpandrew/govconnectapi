# %%
import requests
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
from datetime import datetime, timedelta
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Download and create a dataset of contracts

# %%
session = {"endpoint":"https://governmentconnect.herokuapp.com/"}
session = {"endpoint":"http://127.0.0.1:5000/"}#

QUERY_ENDPOINT = session['endpoint']+"contracts_data?page=0"
uResponse = requests.get(url = QUERY_ENDPOINT)
query_data = json.loads(uResponse.text)
pages = int(query_data['pages'])
pages = 50 # force the maximum number of pages ***** TEMP ******

df = pd.DataFrame()

for i in range(pages):
    QUERY_ENDPOINT = session['endpoint']+"contracts_data?page="+str(i+1)
    uResponse = requests.get(url = QUERY_ENDPOINT)
    query_data = json.loads(uResponse.text)
    df_temp = json_normalize(query_data['data'])
    df = pd.concat([df, df_temp], sort=False)

df = df.drop(['branch', 'division', 'son', 'unspsc'], axis=1) # drop the json 'column headers'
df
# Out:
#                                   agency.display_title  agency.id                                       agency.title  agency_reference_id        atm_austender_id                               branch.display_title  branch.id                                       branch.title                                category_temp_title      cn_id confidentiality_contract confidentiality_outputs                                 contact_name  contract_duration contract_end contract_start contract_value                                        description                             division.display_title  division.id                                     division.title     id original_contract_value   procurement_method publish_date  role son.austender_id  son.id supplier.abn                          supplier.display_name  supplier.id                                  supplier.name                                              title  unspsc.id unspsc.level  unspsc.level_int  unspsc.parent_id  \
# 0                                Department of Defence         10                              Department of defence           4501079098                    None                                            Asd-Ats        6.0                                            Asd-ats     Aerospace systems and components and equipment  CN3616262                       No                      No                                      ASD-ATS                 14   2019-08-09     2019-07-26       11880.00        Aerospace systems, components and equipment                                               Casg          4.0                                               Casg   9491                       0       Limited tender   2019-08-01  None              NaN     NaN  37005285101                         Ruag Australia Pty Ltd         2283                         Ruag australia pty ltd        Aerospace systems, components and equipment      174.0       family               2.0              61.0
# 1                                Department of Defence         10                              Department of defence               6S59QH                    None                                                NaN        NaN                                                NaN         Heavy construction machinery and equipment  CN3615731                       No                      No                 VCDF Joint Logistics Command                 30   2019-08-18     2019-07-19       13143.61                                   Vehicle repairs.                                               Vcdf          5.0                                               Vcdf   9502                       0       Limited tender   2019-07-31  None              NaN     NaN  29117832739                                    Ntp Pty Ltd          327                                    Ntp pty ltd                                   Vehicle repairs.      135.0       family               2.0             134.0
# 2       Australian Competition and Consumer Commission          7     Australian competition and consumer commission               200038                                                       Corporate Management        4.0                               Corporate management                       Temporary personnel services  CN3616047                       No                      No                          Procurement Officer                 92   2019-10-25     2019-07-25       28750.00                  Temporary Payroll Liaison Officer                               Corporate Management          7.0                               Corporate management   9498                       0          Open tender   2019-07-31  None       SON3557594    98.0  21002888762             Hudson Global Resources (Aust) P/L           69             Hudson global resources (aust) p/l                  Temporary Payroll Liaison Officer       71.0        class               3.0              70.0
# 3       Department of Industry, Innovation and Science          9     Department of industry, innovation and science  ORDER_DEED-016971-0                                                                    Finance       22.0                                            Finance                                     Legal services  CN3616989                       No                     Yes                          MANAGER PROCUREMENT                 97   2019-09-30     2019-06-25       19381.00                                     Legal Services                                          Corporate         20.0                                          Corporate   9501                       0  Prequalified tender   2019-08-02  None       SON3520421   169.0  22041424954                                          King           284                                          King                                      Legal Services       33.0       family               2.0               7.0
# 11   Audio and visual presentation and composing eq...      45110000
# 12                        Temporary personnel services      80111600
# 13                                   Research programs      93131703
# 14                        Management advisory services      80100000
# 15                                   Events management      80141607
# 16                     Education and training services      86000000
# 17                                 Travel facilitation      90120000
# 18                                   Computer services      81110000
# 19                        Management advisory services      80100000
# 20           Hotels and lodging and meeting facilities      90110000
# 21                        Management advisory services      80100000
# 22                                                 NaN           NaN
# 23                        Temporary personnel services      80111600
# 24                        Temporary personnel services      80111600
# 25                        Management advisory services      80100000
# 26                        Temporary personnel services      80111600
# 27                                   Internet services      81112100
# 28                     Education and training services      86000000
# 29                        Management advisory services      80100000
# ..                                                 ...           ...
# 134                                                NaN           NaN
# 135                                                NaN           NaN
# 136                                                NaN           NaN
# 137                                                NaN           NaN
# 138                                                NaN           NaN
# 139                                                NaN           NaN
# 140                                                NaN           NaN
# 141                                                NaN           NaN
# 142                                                NaN           NaN
# 143                                                NaN           NaN
# 144                                                NaN           NaN
# 145                                                NaN           NaN
# 146                                                NaN           NaN
# 147                                                NaN           NaN
# 148                                                NaN           NaN
# 149                                                NaN           NaN
# 150                                                NaN           NaN
# 151                                                NaN           NaN
# 152                                                NaN           NaN
# 153                                                NaN           NaN
# 154                                                NaN           NaN
# 155                                                NaN           NaN
# 156                                                NaN           NaN
# 157                                                NaN           NaN
# 158                                                NaN           NaN
# 159                                                NaN           NaN
# 160                                                NaN           NaN
# 161                                                NaN           NaN
# 162                                                NaN           NaN
# 163                                                NaN           NaN
#
# [1364 rows x 39 columns]

# %%
df['dt_publish_date'] = pd.to_datetime(df['publish_date'])
df['dt_contract_start'] = pd.to_datetime(df['contract_start'])
df['dt_contract_end'] = pd.to_datetime(df['contract_end'])
df['month'] = df['dt_contract_start'].map(lambda x: x.month)
df['calendar_year'] = df['dt_contract_start'].map(lambda x: x.year)

df['contract_value'] = df['contract_value'].astype(str)
df[~df.contract_value.str.contains("Original")]
df['contract_value'] = df['contract_value'].astype(float)
df['financial_year'] = pd.to_datetime(df.dt_contract_start).dt.to_period('A-JUN')
df['financial_year'] = df['financial_year'].map(lambda x: x.year).astype(int)
df["contract_ongoing"] = df["dt_contract_end"] > datetime.now() # Is the contract still open?
df["contract_ending_soon"] = df["dt_contract_end"] > datetime.now()-timedelta(days=30) # Is the contract still open?

# get the number of years back 
df['current_fy'] = datetime.now()
df['current_fy'] = pd.to_datetime(df.current_fy).dt.to_period('A-JUN')
df['current_fy'] = df['current_fy'].map(lambda x: x.year).astype(int)
df['years_back'] = df['current_fy'].astype(int)-df['financial_year'].astype(int)

# Fill all of the gaps in the data
df = df.fillna("")

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-98fd6ba1cb26> in <module>()
#       5 df['calendar_year'] = df['dt_contract_start'].map(lambda x: x.year)
#       6
# ----> 7 df[~df.contract_value.str.contains("Original")]
#       8 df['contract_value'] = df['contract_value'].astype(float)
#       9 df['financial_year'] = pd.to_datetime(df.dt_contract_start).dt.to_period('A-JUN')
#
# /Users/benjaminandrew/Documents/bootstrap_api/env/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /Users/benjaminandrew/Documents/bootstrap_api/env/lib/python2.7/site-packages/pandas/core/accessor.pyc in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# /Users/benjaminandrew/Documents/bootstrap_api/env/lib/python2.7/site-packages/pandas/core/strings.pyc in __init__(self, data)
#    1794
#    1795     def __init__(self, data):
# -> 1796         self._validate(data)
#    1797         self._is_categorical = is_categorical_dtype(data)
#    1798
#
# /Users/benjaminandrew/Documents/bootstrap_api/env/lib/python2.7/site-packages/pandas/core/strings.pyc in _validate(data)
#    1816             # (instead of test for object dtype), but that isn't practical for
#    1817             # performance reasons until we have a str dtype (GH 9343)
# -> 1818             raise AttributeError("Can only use .str accessor with string "
#    1819                                  "values, which use np.object_ dtype in "
#    1820                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
#df['agency.id'].nunique() # number of agencies in this df
#df['month'].value_counts() # number of records/contracts per month in this df

# %% [markdown]
# ## Find the average cost of contracts in this category

# %%
agency_id = 5 #10
category_id = 141

df_op = df.copy()
df_op['count']=1
df_op = df_op[df_op['agency.id']==agency_id]
df_op = df_op[df_op['unspsc.id']==category_id]

df_op
# Out:
# Empty DataFrame
# Columns: [agency.display_title, agency.id, agency.title, agency_reference_id, atm_austender_id, branch.display_title, branch.id, branch.title, category_temp_title, cn_id, confidentiality_contract, confidentiality_outputs, contact_name, contract_duration, contract_end, contract_start, contract_value, description, division.display_title, division.id, division.title, id, original_contract_value, procurement_method, publish_date, role, son.austender_id, son.id, supplier.abn, supplier.display_name, supplier.id, supplier.name, title, unspsc.id, unspsc.level, unspsc.level_int, unspsc.parent_id, unspsc.title, unspsc.unspsc, dt_publish_date, month, year, fy, dt_contract_start, calendar_year, financial_year, dt_contract_end, contract_ongiong, contract_ongoing, current_fy, years_back, contract_ending_soon, count]
# Index: []

# %%
contract_data = {}

# Save ALL of the contracts to JSON
contract_data['contracts'] = []
for index, row in df_op.iterrows():
    temp_data = {"agency":row['agency.display_title'], "branch":row['branch.display_title'], "division":row['division.display_title'], "contract_end":row['contract_end'], "contract_start":row['contract_start'], "contract_value":row['contract_value'], "supplier_name":row['supplier.name'], "supplier_id":row['supplier.id'], "title":row['title'], "contract_ongoing":row['contract_ongoing'], "years_back":row['years_back'], "financial_year":row['financial_year']}
    contract_data['contracts'].append(temp_data) 
    
contract_data
# Out:
# {'contracts': [{'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 39572.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-06-26',
#    'contract_value': 25929.2,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 842,
#    'supplier_name': u'Babcock pty ltd',
#    'title': u'Air Reducing Station Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 74250.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'To satisfy LNIDS JFRR-BDJNL',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-02-29',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 82582.39,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-12',
#    'contract_value': 57616.9,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2549,
#    'supplier_name': u'Cea technologies pty ltd',
#    'title': u'Comms Supportability Assessment',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 12325.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2022-12-31',
#    'contract_ongoing': True,
#    'contract_start': u'2018-01-01',
#    'contract_value': 13054.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 59,
#    'supplier_name': u'Saab australia pty ltd',
#    'title': u'Warship Asset Management Agreement Program',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 61710.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2338,
#    'supplier_name': u'Innovation composites pty ltd',
#    'title': u'Repair of watercraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-13',
#    'contract_ongoing': False,
#    'contract_start': u'2019-05-10',
#    'contract_value': 10474.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-10-25',
#    'contract_ongoing': True,
#    'contract_start': u'2019-09-09',
#    'contract_value': 62419.34,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 311,
#    'supplier_name': u'H i fraser pty ltd',
#    'title': u'HP Air Charging System Planned Maintenance',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-11-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-19',
#    'contract_value': 14935.8,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 748,
#    'supplier_name': u'Australian pump industries pty.',
#    'title': u'Electric Motors',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-23',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 27005.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 937,
#    'supplier_name': u'Rfd (australia) pty ltd',
#    'title': u'Supply of diving products',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-03-26',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-18',
#    'contract_value': 63355.94,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Ventilation Fan',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-04-18',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-21',
#    'contract_value': 10823.49,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment consumable items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-06-04',
#    'contract_ongoing': False,
#    'contract_start': u'2019-03-05',
#    'contract_value': 10006.34,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-29',
#    'contract_ongoing': False,
#    'contract_start': u'2019-07-15',
#    'contract_value': 19180.7,
#    'division': u'Vcdf',
#    'financial_year': 2020,
#    'supplier_id': 2376,
#    'supplier_name': u'Tims fabrications',
#    'title': u'weld military waterdraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 17014.09,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'Digital Computer System',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg - General Manager Programs',
#    'contract_end': u'2020-05-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-13',
#    'contract_value': 165000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2233,
#    'supplier_name': u'Asc awd shipbuilder pty ltd',
#    'title': u'HR Support Services',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-01-31',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 14917.82,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-30',
#    'contract_value': 29026.29,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump repair',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 11450.6,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-02-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 10402.21,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 196,
#    'supplier_name': u'Bae systems australia defence pt',
#    'title': u'Belt Flat',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 10116.3,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-04-05',
#    'contract_value': 17164.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 25044.85,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-29',
#    'contract_value': 100410.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 16547.78,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36667.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36866.69,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 24150.5,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 11366.19,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 48854.06,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 25007.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 11170.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 14776.9,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 20654.41,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-01-31',
#    'contract_value': 17036.94,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 41290.7,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2398,
#    'supplier_name': u'Ikad engineering pty ltd',
#    'title': u'Pressure Transmitters.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-02',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 17512.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 46,
#    'supplier_name': u'Sonartech atlas pty limited',
#    'title': u'Access door hinge',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 33198.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2690,
#    'supplier_name': u'Bellinger instruments pty ltd',
#    'title': u'Circuit Cards.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2017-11-30',
#    'contract_value': 15500.0,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-22',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-31',
#    'contract_value': 11632.26,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-07',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-08',
#    'contract_value': 20381.9,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2693,
#    'supplier_name': u'Rolls royce australia services',
#    'title': u'Hose Kit Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-30',
#    'contract_value': 13221.72,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-14',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 61438.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-11',
#    'contract_value': 14910.08,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Refrigeration Compressor Repairs.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-05',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-07',
#    'contract_value': 10202.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2019-06-05',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-14',
#    'contract_value': 4400000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'HMAS HUON EMP(D) 2019',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2018-08-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 22613.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Planned Maintenance of Ship',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-26',
#    'contract_value': 32286.12,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Gun replacement',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-30',
#    'contract_value': 532695.61,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Engineering Deliverables',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg-Ships Division',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-24',
#    'contract_value': 10160.87,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 141,
#    'supplier_name': u'Penske power systems pty ltd',
#    'title': u'Repair of Alternator Shaft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 146876.2,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2}]}

# %%
contract_data['agency_id'] = agency_id
contract_data['category_id'] = category_id

# Number of contracts in the df
contract_data['no_contracts'] = df_op['id'].count()

# Average value of contracts
contract_data['avg_value'] = df_op['contract_value'].mean()

# number of suppliers
contract_data['no_suppliers'] = df_op['supplier.id'].nunique()

# Contracts awarded per month
month_count = df_op['month'].value_counts() # number of records/contracts per month in this df
contract_data['avg_contracts_month'] = sum(month_count) / len(month_count)
contract_data['contracts_month'] = month_count.to_dict()

# Get the earnings per supplier
contract_data['supplier_data'] = []

contract_data
# Out:
# {'agency_id': 10,
#  'avg_contracts_month': 6,
#  'avg_value': 125147.40169811323,
#  'category_id': 157,
#  'contracts': [{'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 39572.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-06-26',
#    'contract_value': 25929.2,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 842,
#    'supplier_name': u'Babcock pty ltd',
#    'title': u'Air Reducing Station Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 74250.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'To satisfy LNIDS JFRR-BDJNL',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-02-29',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 82582.39,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-12',
#    'contract_value': 57616.9,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2549,
#    'supplier_name': u'Cea technologies pty ltd',
#    'title': u'Comms Supportability Assessment',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 12325.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2022-12-31',
#    'contract_ongoing': True,
#    'contract_start': u'2018-01-01',
#    'contract_value': 13054.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 59,
#    'supplier_name': u'Saab australia pty ltd',
#    'title': u'Warship Asset Management Agreement Program',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 61710.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2338,
#    'supplier_name': u'Innovation composites pty ltd',
#    'title': u'Repair of watercraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-13',
#    'contract_ongoing': False,
#    'contract_start': u'2019-05-10',
#    'contract_value': 10474.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-10-25',
#    'contract_ongoing': True,
#    'contract_start': u'2019-09-09',
#    'contract_value': 62419.34,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 311,
#    'supplier_name': u'H i fraser pty ltd',
#    'title': u'HP Air Charging System Planned Maintenance',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-11-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-19',
#    'contract_value': 14935.8,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 748,
#    'supplier_name': u'Australian pump industries pty.',
#    'title': u'Electric Motors',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-23',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 27005.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 937,
#    'supplier_name': u'Rfd (australia) pty ltd',
#    'title': u'Supply of diving products',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-03-26',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-18',
#    'contract_value': 63355.94,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Ventilation Fan',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-04-18',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-21',
#    'contract_value': 10823.49,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment consumable items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-06-04',
#    'contract_ongoing': False,
#    'contract_start': u'2019-03-05',
#    'contract_value': 10006.34,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-29',
#    'contract_ongoing': False,
#    'contract_start': u'2019-07-15',
#    'contract_value': 19180.7,
#    'division': u'Vcdf',
#    'financial_year': 2020,
#    'supplier_id': 2376,
#    'supplier_name': u'Tims fabrications',
#    'title': u'weld military waterdraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 17014.09,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'Digital Computer System',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg - General Manager Programs',
#    'contract_end': u'2020-05-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-13',
#    'contract_value': 165000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2233,
#    'supplier_name': u'Asc awd shipbuilder pty ltd',
#    'title': u'HR Support Services',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-01-31',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 14917.82,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-30',
#    'contract_value': 29026.29,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump repair',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 11450.6,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-02-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 10402.21,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 196,
#    'supplier_name': u'Bae systems australia defence pt',
#    'title': u'Belt Flat',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 10116.3,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-04-05',
#    'contract_value': 17164.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 25044.85,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-29',
#    'contract_value': 100410.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 16547.78,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36667.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36866.69,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 24150.5,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 11366.19,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 48854.06,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 25007.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 11170.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 14776.9,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 20654.41,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-01-31',
#    'contract_value': 17036.94,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 41290.7,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2398,
#    'supplier_name': u'Ikad engineering pty ltd',
#    'title': u'Pressure Transmitters.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-02',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 17512.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 46,
#    'supplier_name': u'Sonartech atlas pty limited',
#    'title': u'Access door hinge',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 33198.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2690,
#    'supplier_name': u'Bellinger instruments pty ltd',
#    'title': u'Circuit Cards.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2017-11-30',
#    'contract_value': 15500.0,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-22',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-31',
#    'contract_value': 11632.26,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-07',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-08',
#    'contract_value': 20381.9,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2693,
#    'supplier_name': u'Rolls royce australia services',
#    'title': u'Hose Kit Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-30',
#    'contract_value': 13221.72,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-14',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 61438.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-11',
#    'contract_value': 14910.08,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Refrigeration Compressor Repairs.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-05',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-07',
#    'contract_value': 10202.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2019-06-05',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-14',
#    'contract_value': 4400000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'HMAS HUON EMP(D) 2019',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2018-08-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 22613.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Planned Maintenance of Ship',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-26',
#    'contract_value': 32286.12,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Gun replacement',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-30',
#    'contract_value': 532695.61,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Engineering Deliverables',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg-Ships Division',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-24',
#    'contract_value': 10160.87,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 141,
#    'supplier_name': u'Penske power systems pty ltd',
#    'title': u'Repair of Alternator Shaft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 146876.2,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2}],
#  'contracts_month': {1: 4, 3: 3, 4: 1, 5: 7, 6: 3, 7: 33, 9: 1, 11: 1},
#  'no_contracts': 53,
#  'no_suppliers': 20,
#  'supplier_data': []}

# %%
df_temp = df_op.groupby(['supplier.display_name']).sum().reset_index()
df_temp = df_temp.sort_values(by='contract_value', ascending=0)
for index, row in df_temp.iterrows():
    temp_data = {"earnings":row['contract_value'], "no_contracts":row['count'], "name":row['supplier.display_name'], "avg_duration":row['contract_duration']/row['count'], "avg_value":row['contract_value']/row['count']}
    contract_data['supplier_data'].append(temp_data) 

no_contracts = df_temp['count'].sum()
total_value = df_temp['contract_value'].sum()

df_top10 = df_temp[:10].copy()
contract_data['supplier_pie_chart'] = []
# Get the top 10 suppliers and format the pie chart data
for index, row in df_top10.iterrows():
    temp_data = {"earnings":int(row['contract_value']), "no_contracts":row['count'], "name":row['supplier.display_name']}
    contract_data['supplier_pie_chart'].append(temp_data)

# Find the remainder of contracts 
if len(df_temp)>10:
    other_contracts = no_contracts - df_top10['count'].sum()
    other_value = total_value - df_top10['contract_value'].sum()
    temp_data = {"earnings":other_value, "no_contracts":other_contracts, "name":"Other"}
    contract_data['supplier_pie_chart'].append(temp_data)
    
contract_data
# Out:
# {'agency_id': 10,
#  'avg_contracts_month': 6,
#  'avg_value': 125147.40169811323,
#  'category_id': 157,
#  'contracts': [{'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 39572.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-06-26',
#    'contract_value': 25929.2,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 842,
#    'supplier_name': u'Babcock pty ltd',
#    'title': u'Air Reducing Station Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 74250.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'To satisfy LNIDS JFRR-BDJNL',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-02-29',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 82582.39,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-12',
#    'contract_value': 57616.9,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2549,
#    'supplier_name': u'Cea technologies pty ltd',
#    'title': u'Comms Supportability Assessment',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 12325.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2022-12-31',
#    'contract_ongoing': True,
#    'contract_start': u'2018-01-01',
#    'contract_value': 13054.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 59,
#    'supplier_name': u'Saab australia pty ltd',
#    'title': u'Warship Asset Management Agreement Program',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 61710.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2338,
#    'supplier_name': u'Innovation composites pty ltd',
#    'title': u'Repair of watercraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-13',
#    'contract_ongoing': False,
#    'contract_start': u'2019-05-10',
#    'contract_value': 10474.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-10-25',
#    'contract_ongoing': True,
#    'contract_start': u'2019-09-09',
#    'contract_value': 62419.34,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 311,
#    'supplier_name': u'H i fraser pty ltd',
#    'title': u'HP Air Charging System Planned Maintenance',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-11-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-19',
#    'contract_value': 14935.8,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 748,
#    'supplier_name': u'Australian pump industries pty.',
#    'title': u'Electric Motors',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-23',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 27005.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 937,
#    'supplier_name': u'Rfd (australia) pty ltd',
#    'title': u'Supply of diving products',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-03-26',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-18',
#    'contract_value': 63355.94,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Ventilation Fan',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-04-18',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-21',
#    'contract_value': 10823.49,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment consumable items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-06-04',
#    'contract_ongoing': False,
#    'contract_start': u'2019-03-05',
#    'contract_value': 10006.34,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-29',
#    'contract_ongoing': False,
#    'contract_start': u'2019-07-15',
#    'contract_value': 19180.7,
#    'division': u'Vcdf',
#    'financial_year': 2020,
#    'supplier_id': 2376,
#    'supplier_name': u'Tims fabrications',
#    'title': u'weld military waterdraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 17014.09,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'Digital Computer System',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg - General Manager Programs',
#    'contract_end': u'2020-05-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-13',
#    'contract_value': 165000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2233,
#    'supplier_name': u'Asc awd shipbuilder pty ltd',
#    'title': u'HR Support Services',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-01-31',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 14917.82,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-30',
#    'contract_value': 29026.29,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump repair',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 11450.6,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-02-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 10402.21,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 196,
#    'supplier_name': u'Bae systems australia defence pt',
#    'title': u'Belt Flat',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 10116.3,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-04-05',
#    'contract_value': 17164.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 25044.85,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-29',
#    'contract_value': 100410.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 16547.78,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36667.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36866.69,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 24150.5,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 11366.19,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 48854.06,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 25007.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 11170.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 14776.9,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 20654.41,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-01-31',
#    'contract_value': 17036.94,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 41290.7,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2398,
#    'supplier_name': u'Ikad engineering pty ltd',
#    'title': u'Pressure Transmitters.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-02',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 17512.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 46,
#    'supplier_name': u'Sonartech atlas pty limited',
#    'title': u'Access door hinge',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 33198.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2690,
#    'supplier_name': u'Bellinger instruments pty ltd',
#    'title': u'Circuit Cards.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2017-11-30',
#    'contract_value': 15500.0,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-22',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-31',
#    'contract_value': 11632.26,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-07',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-08',
#    'contract_value': 20381.9,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2693,
#    'supplier_name': u'Rolls royce australia services',
#    'title': u'Hose Kit Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-30',
#    'contract_value': 13221.72,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-14',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 61438.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-11',
#    'contract_value': 14910.08,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Refrigeration Compressor Repairs.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-05',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-07',
#    'contract_value': 10202.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2019-06-05',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-14',
#    'contract_value': 4400000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'HMAS HUON EMP(D) 2019',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2018-08-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 22613.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Planned Maintenance of Ship',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-26',
#    'contract_value': 32286.12,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Gun replacement',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-30',
#    'contract_value': 532695.61,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Engineering Deliverables',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg-Ships Division',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-24',
#    'contract_value': 10160.87,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 141,
#    'supplier_name': u'Penske power systems pty ltd',
#    'title': u'Repair of Alternator Shaft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 146876.2,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2}],
#  'contracts_month': {1: 4, 3: 3, 4: 1, 5: 7, 6: 3, 7: 33, 9: 1, 11: 1},
#  'division_contracts': [{'avg_contract_duration': 133,
#    'avg_contract_value': 127185.22288461539,
#    'contract_count': 52,
#    'division_title': u'Casg',
#    'sum_contracts': 6613631.59},
#   {'avg_contract_duration': 14,
#    'avg_contract_value': 19180.7,
#    'contract_count': 1,
#    'division_title': u'Vcdf',
#    'sum_contracts': 19180.7}],
#  'no_contracts': 53,
#  'no_suppliers': 20,
#  'supplier_data': [{'avg_duration': 102,
#    'avg_value': 193030.93433333334,
#    'earnings': 5790928.03,
#    'name': u'Thales Australia Limited',
#    'no_contracts': 30},
#   {'avg_duration': 365,
#    'avg_value': 165000.0,
#    'earnings': 165000.0,
#    'name': u'Asc Awd Shipbuilder Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 45632.045,
#    'earnings': 91264.09,
#    'name': u'Milspec Services Pty Limited',
#    'no_contracts': 2},
#   {'avg_duration': 178,
#    'avg_value': 39133.01,
#    'earnings': 78266.02,
#    'name': u'Noske-Kaeser Marine Australia Pt',
#    'no_contracts': 2},
#   {'avg_duration': 46,
#    'avg_value': 62419.34,
#    'earnings': 62419.34,
#    'name': u'H I Fraser Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 74,
#    'avg_value': 61710.0,
#    'earnings': 61710.0,
#    'name': u'Innovation Composites Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 123,
#    'avg_value': 57616.9,
#    'earnings': 57616.9,
#    'name': u'Cea Technologies Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 30,
#    'avg_value': 25949.0,
#    'earnings': 51898.0,
#    'name': u'Vega Australia Pty Ltd',
#    'no_contracts': 2},
#   {'avg_duration': 7,
#    'avg_value': 41290.7,
#    'earnings': 41290.7,
#    'name': u'Ikad Engineering Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 101,
#    'avg_value': 20329.275,
#    'earnings': 40658.55,
#    'name': u'Weir Minerals Australia',
#    'no_contracts': 2},
#   {'avg_duration': 70,
#    'avg_value': 33198.0,
#    'earnings': 33198.0,
#    'name': u'Bellinger Instruments Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 70,
#    'avg_value': 27005.0,
#    'earnings': 27005.0,
#    'name': u'Rfd (Australia) Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 93,
#    'avg_value': 25929.2,
#    'earnings': 25929.2,
#    'name': u'Babcock Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 60,
#    'avg_value': 20381.9,
#    'earnings': 20381.9,
#    'name': u'Rolls Royce Australia Services',
#    'no_contracts': 1},
#   {'avg_duration': 14,
#    'avg_value': 19180.7,
#    'earnings': 19180.7,
#    'name': u'Tims Fabrications',
#    'no_contracts': 1},
#   {'avg_duration': 77,
#    'avg_value': 17512.0,
#    'earnings': 17512.0,
#    'name': u'Sonartech Atlas Pty Limited',
#    'no_contracts': 1},
#   {'avg_duration': 120,
#    'avg_value': 14935.8,
#    'earnings': 14935.8,
#    'name': u'Australian Pump Industries Pty.',
#    'no_contracts': 1},
#   {'avg_duration': 1825,
#    'avg_value': 13054.98,
#    'earnings': 13054.98,
#    'name': u'Saab Australia Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 224,
#    'avg_value': 10402.21,
#    'earnings': 10402.21,
#    'name': u'Bae Systems Australia Defence Pt',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 10160.87,
#    'earnings': 10160.87,
#    'name': u'Penske Power Systems Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 102,
#    'avg_value': 193030.93433333334,
#    'earnings': 5790928.03,
#    'name': u'Thales Australia Limited',
#    'no_contracts': 30},
#   {'avg_duration': 365,
#    'avg_value': 165000.0,
#    'earnings': 165000.0,
#    'name': u'Asc Awd Shipbuilder Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 45632.045,
#    'earnings': 91264.09,
#    'name': u'Milspec Services Pty Limited',
#    'no_contracts': 2},
#   {'avg_duration': 178,
#    'avg_value': 39133.01,
#    'earnings': 78266.02,
#    'name': u'Noske-Kaeser Marine Australia Pt',
#    'no_contracts': 2},
#   {'avg_duration': 46,
#    'avg_value': 62419.34,
#    'earnings': 62419.34,
#    'name': u'H I Fraser Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 74,
#    'avg_value': 61710.0,
#    'earnings': 61710.0,
#    'name': u'Innovation Composites Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 123,
#    'avg_value': 57616.9,
#    'earnings': 57616.9,
#    'name': u'Cea Technologies Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 30,
#    'avg_value': 25949.0,
#    'earnings': 51898.0,
#    'name': u'Vega Australia Pty Ltd',
#    'no_contracts': 2},
#   {'avg_duration': 7,
#    'avg_value': 41290.7,
#    'earnings': 41290.7,
#    'name': u'Ikad Engineering Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 101,
#    'avg_value': 20329.275,
#    'earnings': 40658.55,
#    'name': u'Weir Minerals Australia',
#    'no_contracts': 2},
#   {'avg_duration': 70,
#    'avg_value': 33198.0,
#    'earnings': 33198.0,
#    'name': u'Bellinger Instruments Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 70,
#    'avg_value': 27005.0,
#    'earnings': 27005.0,
#    'name': u'Rfd (Australia) Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 93,
#    'avg_value': 25929.2,
#    'earnings': 25929.2,
#    'name': u'Babcock Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 60,
#    'avg_value': 20381.9,
#    'earnings': 20381.9,
#    'name': u'Rolls Royce Australia Services',
#    'no_contracts': 1},
#   {'avg_duration': 14,
#    'avg_value': 19180.7,
#    'earnings': 19180.7,
#    'name': u'Tims Fabrications',
#    'no_contracts': 1},
#   {'avg_duration': 77,
#    'avg_value': 17512.0,
#    'earnings': 17512.0,
#    'name': u'Sonartech Atlas Pty Limited',
#    'no_contracts': 1},
#   {'avg_duration': 120,
#    'avg_value': 14935.8,
#    'earnings': 14935.8,
#    'name': u'Australian Pump Industries Pty.',
#    'no_contracts': 1},
#   {'avg_duration': 1825,
#    'avg_value': 13054.98,
#    'earnings': 13054.98,
#    'name': u'Saab Australia Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 224,
#    'avg_value': 10402.21,
#    'earnings': 10402.21,
#    'name': u'Bae Systems Australia Defence Pt',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 10160.87,
#    'earnings': 10160.87,
#    'name': u'Penske Power Systems Pty Ltd',
#    'no_contracts': 1}],
#  'supplier_pie_chart': []}

# %%
df_temp = df_op.groupby(['division.id', 'division.display_title']).mean().reset_index()
df_temp
# Out:
#    division.id division.display_title  agency.id  contract_duration  contract_value            id  supplier.id     month         year  calendar_year  financial_year  contract_ongiong  contract_ongoing  current_fy  years_back  contract_ending_soon  count
# 0          4.0                   Casg       10.0         133.673077   127185.222885  10181.519231   555.788462  6.038462  2018.403846    2018.403846     2019.057692          0.365385          0.365385      2020.0    0.942308              0.384615    1.0
# 1          5.0                   Vcdf       10.0          14.000000    19180.700000  10017.000000  2376.000000  7.000000  2019.000000    2019.000000     2020.000000          0.000000          0.000000      2020.0    0.000000              1.000000    1.0

# %%
contract_data['division_contracts'] = []
for index, row in df_temp.iterrows():
    temp_dict = {"division_title":row['division.display_title'], "avg_contract_value":row['contract_value'], "avg_contract_duration":int(row['contract_duration'])}
    contract_data['division_contracts'].append(temp_dict)
contract_data['division_contracts']
# Out:
# [{'avg_contract_duration': 133,
#   'avg_contract_value': 127185.22288461539,
#   'division_title': u'Casg'},
#  {'avg_contract_duration': 14,
#   'avg_contract_value': 19180.7,
#   'division_title': u'Vcdf'}]

# %%
df_temp = df_op.groupby(['division.id', 'division.display_title']).sum().reset_index()
for index, row in df_temp.iterrows():
    contract_data['division_contracts'][index]['sum_contracts']=row['contract_value']
    contract_data['division_contracts'][index]['contract_count']=row['count']
    
contract_data
# Out:
# {'agency_id': 10,
#  'avg_contracts_month': 6,
#  'avg_value': 125147.40169811323,
#  'category_id': 157,
#  'contracts': [{'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 39572.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-06-26',
#    'contract_value': 25929.2,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 842,
#    'supplier_name': u'Babcock pty ltd',
#    'title': u'Air Reducing Station Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-17',
#    'contract_value': 74250.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'To satisfy LNIDS JFRR-BDJNL',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-02-29',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 82582.39,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-12',
#    'contract_value': 57616.9,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2549,
#    'supplier_name': u'Cea technologies pty ltd',
#    'title': u'Comms Supportability Assessment',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 12325.5,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 1666,
#    'supplier_name': u'Vega australia pty ltd',
#    'title': u'Pressure Transmitters',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2022-12-31',
#    'contract_ongoing': True,
#    'contract_start': u'2018-01-01',
#    'contract_value': 13054.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 59,
#    'supplier_name': u'Saab australia pty ltd',
#    'title': u'Warship Asset Management Agreement Program',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 61710.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 2338,
#    'supplier_name': u'Innovation composites pty ltd',
#    'title': u'Repair of watercraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-13',
#    'contract_ongoing': False,
#    'contract_start': u'2019-05-10',
#    'contract_value': 10474.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-10-25',
#    'contract_ongoing': True,
#    'contract_start': u'2019-09-09',
#    'contract_value': 62419.34,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 311,
#    'supplier_name': u'H i fraser pty ltd',
#    'title': u'HP Air Charging System Planned Maintenance',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-11-16',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-19',
#    'contract_value': 14935.8,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 748,
#    'supplier_name': u'Australian pump industries pty.',
#    'title': u'Electric Motors',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-23',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 27005.0,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 937,
#    'supplier_name': u'Rfd (australia) pty ltd',
#    'title': u'Supply of diving products',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-03-26',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-18',
#    'contract_value': 63355.94,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Ventilation Fan',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-04-18',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-21',
#    'contract_value': 10823.49,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment consumable items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-06-04',
#    'contract_ongoing': False,
#    'contract_start': u'2019-03-05',
#    'contract_value': 10006.34,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-07-29',
#    'contract_ongoing': False,
#    'contract_start': u'2019-07-15',
#    'contract_value': 19180.7,
#    'division': u'Vcdf',
#    'financial_year': 2020,
#    'supplier_id': 2376,
#    'supplier_name': u'Tims fabrications',
#    'title': u'weld military waterdraft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-16',
#    'contract_value': 17014.09,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 428,
#    'supplier_name': u'Milspec services pty limited',
#    'title': u'Digital Computer System',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg - General Manager Programs',
#    'contract_end': u'2020-05-12',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-13',
#    'contract_value': 165000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2233,
#    'supplier_name': u'Asc awd shipbuilder pty ltd',
#    'title': u'HR Support Services',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2020-01-31',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 14917.82,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-27',
#    'contract_ongoing': True,
#    'contract_start': u'2019-05-30',
#    'contract_value': 29026.29,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump repair',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-09-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-15',
#    'contract_value': 11450.6,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2019-02-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 10402.21,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 196,
#    'supplier_name': u'Bae systems australia defence pt',
#    'title': u'Belt Flat',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 10116.3,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-04-05',
#    'contract_value': 17164.98,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 25044.85,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-29',
#    'contract_value': 100410.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 16547.78,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36667.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 36866.69,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 24150.5,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-20',
#    'contract_value': 11366.19,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 48854.06,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment New Inventory',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 25007.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 11170.89,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 14776.9,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-18',
#    'contract_value': 20654.41,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-01-31',
#    'contract_value': 17036.94,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 41290.7,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2398,
#    'supplier_name': u'Ikad engineering pty ltd',
#    'title': u'Pressure Transmitters.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-10-02',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-17',
#    'contract_value': 17512.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 46,
#    'supplier_name': u'Sonartech atlas pty limited',
#    'title': u'Access door hinge',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-19',
#    'contract_value': 33198.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 2690,
#    'supplier_name': u'Bellinger instruments pty ltd',
#    'title': u'Circuit Cards.',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2017-11-30',
#    'contract_value': 15500.0,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-22',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-31',
#    'contract_value': 11632.26,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2385,
#    'supplier_name': u'Weir minerals australia',
#    'title': u'Pump Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-07',
#    'contract_ongoing': False,
#    'contract_start': u'2018-06-08',
#    'contract_value': 20381.9,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 2693,
#    'supplier_name': u'Rolls royce australia services',
#    'title': u'Hose Kit Repair.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-30',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-30',
#    'contract_value': 13221.72,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-09-14',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 61438.98,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-23',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-11',
#    'contract_value': 14910.08,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 386,
#    'supplier_name': u'Noske-kaeser marine australia pt',
#    'title': u'Refrigeration Compressor Repairs.',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-08-05',
#    'contract_ongoing': False,
#    'contract_start': u'2018-05-07',
#    'contract_value': 10202.71,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Consumable Items',
#    'years_back': 2},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2019-06-05',
#    'contract_ongoing': False,
#    'contract_start': u'2019-01-14',
#    'contract_value': 4400000.0,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'HMAS HUON EMP(D) 2019',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Commercial Group',
#    'contract_end': u'2018-08-27',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-16',
#    'contract_value': 22613.99,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Planned Maintenance of Ship',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2018-08-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-07-26',
#    'contract_value': 32286.12,
#    'division': u'Casg',
#    'financial_year': 2019,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Gun replacement',
#    'years_back': 1},
#   {'agency': u'Department of Defence',
#    'branch': u'Msd - Maritime Systems Division',
#    'contract_end': u'2019-11-15',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-30',
#    'contract_value': 532695.61,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Engineering Deliverables',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': u'Casg-Ships Division',
#    'contract_end': u'2019-08-30',
#    'contract_ongoing': True,
#    'contract_start': u'2019-07-24',
#    'contract_value': 10160.87,
#    'division': u'Casg',
#    'financial_year': 2020,
#    'supplier_id': 141,
#    'supplier_name': u'Penske power systems pty ltd',
#    'title': u'Repair of Alternator Shaft',
#    'years_back': 0},
#   {'agency': u'Department of Defence',
#    'branch': '',
#    'contract_end': u'2018-07-31',
#    'contract_ongoing': False,
#    'contract_start': u'2018-03-15',
#    'contract_value': 146876.2,
#    'division': u'Casg',
#    'financial_year': 2018,
#    'supplier_id': 33,
#    'supplier_name': u'Thales australia limited',
#    'title': u'Military Equipment Repairs',
#    'years_back': 2}],
#  'contracts_month': {1: 4, 3: 3, 4: 1, 5: 7, 6: 3, 7: 33, 9: 1, 11: 1},
#  'division_contracts': [{'avg_contract_duration': 133,
#    'avg_contract_value': 127185.22288461539,
#    'contract_count': 52,
#    'division_title': u'Casg',
#    'sum_contracts': 6613631.59},
#   {'avg_contract_duration': 14,
#    'avg_contract_value': 19180.7,
#    'contract_count': 1,
#    'division_title': u'Vcdf',
#    'sum_contracts': 19180.7}],
#  'no_contracts': 53,
#  'no_suppliers': 20,
#  'supplier_data': [{'avg_duration': 102,
#    'avg_value': 193030.93433333334,
#    'earnings': 5790928.03,
#    'name': u'Thales Australia Limited',
#    'no_contracts': 30},
#   {'avg_duration': 365,
#    'avg_value': 165000.0,
#    'earnings': 165000.0,
#    'name': u'Asc Awd Shipbuilder Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 45632.045,
#    'earnings': 91264.09,
#    'name': u'Milspec Services Pty Limited',
#    'no_contracts': 2},
#   {'avg_duration': 178,
#    'avg_value': 39133.01,
#    'earnings': 78266.02,
#    'name': u'Noske-Kaeser Marine Australia Pt',
#    'no_contracts': 2},
#   {'avg_duration': 46,
#    'avg_value': 62419.34,
#    'earnings': 62419.34,
#    'name': u'H I Fraser Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 74,
#    'avg_value': 61710.0,
#    'earnings': 61710.0,
#    'name': u'Innovation Composites Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 123,
#    'avg_value': 57616.9,
#    'earnings': 57616.9,
#    'name': u'Cea Technologies Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 30,
#    'avg_value': 25949.0,
#    'earnings': 51898.0,
#    'name': u'Vega Australia Pty Ltd',
#    'no_contracts': 2},
#   {'avg_duration': 7,
#    'avg_value': 41290.7,
#    'earnings': 41290.7,
#    'name': u'Ikad Engineering Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 101,
#    'avg_value': 20329.275,
#    'earnings': 40658.55,
#    'name': u'Weir Minerals Australia',
#    'no_contracts': 2},
#   {'avg_duration': 70,
#    'avg_value': 33198.0,
#    'earnings': 33198.0,
#    'name': u'Bellinger Instruments Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 70,
#    'avg_value': 27005.0,
#    'earnings': 27005.0,
#    'name': u'Rfd (Australia) Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 93,
#    'avg_value': 25929.2,
#    'earnings': 25929.2,
#    'name': u'Babcock Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 60,
#    'avg_value': 20381.9,
#    'earnings': 20381.9,
#    'name': u'Rolls Royce Australia Services',
#    'no_contracts': 1},
#   {'avg_duration': 14,
#    'avg_value': 19180.7,
#    'earnings': 19180.7,
#    'name': u'Tims Fabrications',
#    'no_contracts': 1},
#   {'avg_duration': 77,
#    'avg_value': 17512.0,
#    'earnings': 17512.0,
#    'name': u'Sonartech Atlas Pty Limited',
#    'no_contracts': 1},
#   {'avg_duration': 120,
#    'avg_value': 14935.8,
#    'earnings': 14935.8,
#    'name': u'Australian Pump Industries Pty.',
#    'no_contracts': 1},
#   {'avg_duration': 1825,
#    'avg_value': 13054.98,
#    'earnings': 13054.98,
#    'name': u'Saab Australia Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 224,
#    'avg_value': 10402.21,
#    'earnings': 10402.21,
#    'name': u'Bae Systems Australia Defence Pt',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 10160.87,
#    'earnings': 10160.87,
#    'name': u'Penske Power Systems Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 102,
#    'avg_value': 193030.93433333334,
#    'earnings': 5790928.03,
#    'name': u'Thales Australia Limited',
#    'no_contracts': 30},
#   {'avg_duration': 365,
#    'avg_value': 165000.0,
#    'earnings': 165000.0,
#    'name': u'Asc Awd Shipbuilder Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 45632.045,
#    'earnings': 91264.09,
#    'name': u'Milspec Services Pty Limited',
#    'no_contracts': 2},
#   {'avg_duration': 178,
#    'avg_value': 39133.01,
#    'earnings': 78266.02,
#    'name': u'Noske-Kaeser Marine Australia Pt',
#    'no_contracts': 2},
#   {'avg_duration': 46,
#    'avg_value': 62419.34,
#    'earnings': 62419.34,
#    'name': u'H I Fraser Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 74,
#    'avg_value': 61710.0,
#    'earnings': 61710.0,
#    'name': u'Innovation Composites Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 123,
#    'avg_value': 57616.9,
#    'earnings': 57616.9,
#    'name': u'Cea Technologies Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 30,
#    'avg_value': 25949.0,
#    'earnings': 51898.0,
#    'name': u'Vega Australia Pty Ltd',
#    'no_contracts': 2},
#   {'avg_duration': 7,
#    'avg_value': 41290.7,
#    'earnings': 41290.7,
#    'name': u'Ikad Engineering Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 101,
#    'avg_value': 20329.275,
#    'earnings': 40658.55,
#    'name': u'Weir Minerals Australia',
#    'no_contracts': 2},
#   {'avg_duration': 70,
#    'avg_value': 33198.0,
#    'earnings': 33198.0,
#    'name': u'Bellinger Instruments Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 70,
#    'avg_value': 27005.0,
#    'earnings': 27005.0,
#    'name': u'Rfd (Australia) Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 93,
#    'avg_value': 25929.2,
#    'earnings': 25929.2,
#    'name': u'Babcock Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 60,
#    'avg_value': 20381.9,
#    'earnings': 20381.9,
#    'name': u'Rolls Royce Australia Services',
#    'no_contracts': 1},
#   {'avg_duration': 14,
#    'avg_value': 19180.7,
#    'earnings': 19180.7,
#    'name': u'Tims Fabrications',
#    'no_contracts': 1},
#   {'avg_duration': 77,
#    'avg_value': 17512.0,
#    'earnings': 17512.0,
#    'name': u'Sonartech Atlas Pty Limited',
#    'no_contracts': 1},
#   {'avg_duration': 120,
#    'avg_value': 14935.8,
#    'earnings': 14935.8,
#    'name': u'Australian Pump Industries Pty.',
#    'no_contracts': 1},
#   {'avg_duration': 1825,
#    'avg_value': 13054.98,
#    'earnings': 13054.98,
#    'name': u'Saab Australia Pty Ltd',
#    'no_contracts': 1},
#   {'avg_duration': 224,
#    'avg_value': 10402.21,
#    'earnings': 10402.21,
#    'name': u'Bae Systems Australia Defence Pt',
#    'no_contracts': 1},
#   {'avg_duration': 37,
#    'avg_value': 10160.87,
#    'earnings': 10160.87,
#    'name': u'Penske Power Systems Pty Ltd',
#    'no_contracts': 1}],
#  'supplier_pie_chart': [{'earnings': 5790928,
#    'name': u'Thales Australia Limited',
#    'no_contracts': 30},
#   {'earnings': 165000,
#    'name': u'Asc Awd Shipbuilder Pty Ltd',
#    'no_contracts': 1},
#   {'earnings': 91264,
#    'name': u'Milspec Services Pty Limited',
#    'no_contracts': 2},
#   {'earnings': 78266,
#    'name': u'Noske-Kaeser Marine Australia Pt',
#    'no_contracts': 2},
#   {'earnings': 62419, 'name': u'H I Fraser Pty Ltd', 'no_contracts': 1},
#   {'earnings': 61710,
#    'name': u'Innovation Composites Pty Ltd',
#    'no_contracts': 1},
#   {'earnings': 57616, 'name': u'Cea Technologies Pty Ltd', 'no_contracts': 1},
#   {'earnings': 51898, 'name': u'Vega Australia Pty Ltd', 'no_contracts': 2},
#   {'earnings': 41290, 'name': u'Ikad Engineering Pty Ltd', 'no_contracts': 1},
#   {'earnings': 40658, 'name': u'Weir Minerals Australia', 'no_contracts': 2},
#   {'earnings': 191760.66000000015, 'name': 'Other', 'no_contracts': 10}]}
